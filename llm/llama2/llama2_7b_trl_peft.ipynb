# %% [markdown]
# <a href="https://colab.research.google.com/github/nukano0522/azure_apps/blob/main/llm/llama2/llama2_7b_trl_peft.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install -q transformers trl peft accelerate bitsandbytes
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.6/92.6 MB 9.2 MB/s eta 0:00:00

# %%
! git clone https://github.com/lvwerra/trl
# Out:
# Cloning into 'trl'...
# remote: Enumerating objects: 3813, done.
# remote: Counting objects: 100% (3813/3813), done.
# remote: Compressing objects: 100% (1495/1495), done.
# remote: Total 3813 (delta 2373), reused 3435 (delta 2151), pack-reused 0
# Receiving objects: 100% (3813/3813), 5.71 MiB | 14.72 MiB/s, done.
# Resolving deltas: 100% (2373/2373), done.

# %%
from huggingface_hub import notebook_login
notebook_login()

# %%
! python trl/examples/scripts/sft_trainer.py \
    --model_name meta-llama/Llama-2-7b-hf \
    --dataset_name timdettmers/openassistant-guanaco \
    --load_in_4bit \
    --use_peft \
    --batch_size 4 \
    --gradient_accumulation_steps 2
# Out:
# 2023-07-29 00:54:10.839065: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py:2193: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# ...
# ...
# ...
# Loading checkpoint shards: 100% 2/2 [01:41<00:00, 50.68s/it]
# ...
# Repo card metadata block was not found. Setting CardData to empty.
# ...
# Extracting data files: 100% 2/2 [00:00<00:00, 1444.57it/s]
# Generating train split: 9846 examples [00:00, 42301.96 examples/s]
# Generating test split: 518 examples [00:00, 45533.89 examples/s]
# /usr/local/lib/python3.10/dist-packages/peft/utils/other.py:102: FutureWarning: prepare_model_for_int8_training is deprecated and will be removed in a future version. Use prepare_model_for_kbit_training instead.
#   warnings.warn(
# ...
# Using pad_token, but it is not set yet.
# Map: 100% 9846/9846 [00:11<00:00, 863.70 examples/s]
# ...

# %%
! pip install -q transformers datasets accelerate sentencepiece protobuf==3.20 py7zr scipy peft bitsandbytes fire torch_tb_profiler ipywidgets

# %%
! TRANSFORM=`python -c "import transformers;print('/'.join(transformers.__file__.split('/')[:-1])+'/models/llama/convert_llama_weights_to_hf.py')"`

# %%
! python ${TRANSFORM} --input_dir models --model_size 7B --output_dir models_hf/7B
# Out:
# unknown option --input_dir
# usage: python3 [option] ... [-c cmd | -m mod | file | -] [arg] ...
# Try `python -h' for more information.

# %%
# ! python ${TRANSFORM} --input_dir models --model_size 7B --output_dir models_hf/7B
